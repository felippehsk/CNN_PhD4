# %%
#Importing libraries
import os
import time
import json
import numpy as np
import torch
import pickle
from torch.autograd import Variable
import cv2
from matplotlib import pyplot as plt
from cnn import SegmentationModel as net

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu' 
print(device)
# Out:
# cuda

# %%
class MyArgs():
    def __init__(self):
        self.model = 'ESPNet'
        self.data_dir = './data/'
        self.input_dir = '../../Datasets/'
        self.scaleIn =  1
        self.max_epochs =  1501
        self.num_workers =  4
        self.batch_size =  10
        self.step_loss =  100
        self.lr =  0.005
        self.savedir =  './data/resuts/'
        self.classes =  3
        self.cached_data_file =  './data/Stats.p'
        self.logFile =  'trainValLog.txt'
        self.pretrained =  ''
        self.s =  1.5
        self.resume =  False
        self.resumeLoc =  './data/resuts/checkpoint.pth.tar'
        self.onGPU =  True
        
    def __repr__(self):
        return str(self.__dict__)
    
    def __str__(self):
        return str(self.__dict__)

# %%
args = MyArgs()
args
# Out:
# {'model': 'ESPNet', 'data_dir': './data/', 'input_dir': '../../Datasets/', 'scaleIn': 1, 'max_epochs': 1501, 'num_workers': 4, 'batch_size': 10, 'step_loss': 100, 'lr': 0.005, 'savedir': './data/resuts/', 'classes': 3, 'cached_data_file': './data/Stats.p', 'logFile': 'trainValLog.txt', 'pretrained': '', 's': 1.5, 'resume': False, 'resumeLoc': './data/resuts/checkpoint.pth.tar', 'onGPU': True}

# %%
def calc_tiles(t, i, m):
    n = int(np.round(t/(i-m)))
    if n < 2:
        mc = co = np.array([[0],[t]])
    else:
        tt = np.repeat(np.array([[-.5,.5]]), n - 2, axis= 0)
        tt = np.concatenate([np.array([[0, 1]]), tt, np.array([[-1, 0]])])
        tc = t/n * np.stack([np.arange(n), 1 + np.arange(n)])
        ma = i - (tc[1] - tc[0])
        mc = np.int0(tc + tt.T * ma)
        co = np.int0(np.array([[0],[i]]) - tt.T * ma)
    return(mc, co)

def calc_bb(tw, th, iw, ih, m):
    xc, xco = calc_tiles(tw, iw, m)
    yc, yco = calc_tiles(th, ih, m)
    return([xc, yc, xco, yco])

# %%
def get_cat(img):
    start_time = time.time()
    
    total_width, total_height = img.shape[:2]
    xc, yc, xco, yco = calc_bb(total_width, total_height, input_height, input_width, 40)

    time_taken = time.time() - start_time
    print('PreProc time: %.2f' % time_taken)

    preds_l = []
    for yi in range(yc.shape[1]):
        preds_x = []
        for xi in range(xc.shape[1]):
            preds = np.zeros((classes, xco[1,xi] - xco[0,xi],  yco[1,yi] - yco[0,yi]))
            im = img[xc[0,xi]:xc[1,xi],yc[0,yi]:yc[1,yi]]
            if im.mean() > -5:
                im = im.reshape(np.insert(im.shape, 0, 1))
                im = np.moveaxis(im, 3, 1)
                img_tensor = torch.from_numpy(im)
                img_variable = Variable(img_tensor)
                img_variable = img_variable.to(device=device, dtype=torch.float)
                img_out, states = model(img_variable)
                preds = img_out.cpu().data.numpy()
                preds = preds[0,:,xco[0,xi]:xco[1,xi],yco[0,yi]:yco[1,yi]]
            preds_x.append(preds)

        preds_l.append(np.concatenate(preds_x, 1))

    time_taken = time.time() - start_time - time_taken
    print('Prediction time: %.2f' % time_taken)

    pred = np.concatenate(preds_l, 2)
    
    time_taken = time.time() - start_time
    print('Total time: %.2f' % time_taken)
    return(pred)

# %%
def compare(data, fig, rows, cols ):
    for i in range (0,len(data)):
        plt.figure(fig)
        plt.subplot(rows, cols, i+1)
        plt.imshow(data[i])
    return

# %%
img_dir = '../../Datasets/OFPE/'
img_ext = 'x.npy'
imgs_name = [os.path.join(img_dir, i) for i in sorted(os.listdir(img_dir)) if i.endswith(img_ext)]
num_im = len(imgs_name)
print(num_im)
# Out:
# 100

# %%
model = net.EESPNet_Seg(args.classes, s=args.s)
model_weight_file = './data/resuts/model_1111.pth'
model.load_state_dict(torch.load(model_weight_file))
model = model.cuda()
# set to evaluation mode
model.eval()

data = pickle.load(open(args.cached_data_file, "rb"))

print('Modelo Ok')
# Out:
# Modelo Ok

# %%
input_height = 256
input_width = 256

img_name = imgs_name[50]
img = np.load(img_name)
pred = get_cat(img)
imgs_pred = [pred[i] for i in range(3)]
imgs_rgb = [img[:,:,i] for i in range(3)]
plt.figure(figsize = (15,9))
compare(imgs_rgb + imgs_pred , fig=1, rows=2, cols=3)
# Out:
# PreProc time: 0.00
# Prediction time: 0.03
# Total time: 0.04
